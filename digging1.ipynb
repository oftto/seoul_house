# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 23)
pd.set_option('display.max_rows', False)
pd.set_option('display.width', False)
# %matplotlib inline

# %%
df = pd.read_csv("서울특별시_전월세가_정보_20190916.csv", encoding = 'CP949')
# Out:
# C:\Users\Yeonjoo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,1,2,3,8,11,14,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                   지번코드     기관코드 일련번호  접수년도  자치구코드 자치구명  법정동코드 법정동명  본번    부번  \
# 0  1111010100100740001  3000136  457  2015  11110  종로구  10100  청운동  74  0001
# 1  1111010100100010000  3000136  485  2015  11110  종로구  10100  청운동   1  0000
# 2  1111010100100560041  3000136    5  2016  11110  종로구  10100  청운동  56  0041
# 3  1111010100100500010  3000136  505  2015  11110  종로구  10100  청운동  50  0010
# 4  1111010100100520018  3000136  637  2015  11110  종로구  10100  청운동  52  0018
#
#        건물명  층 임대건물코드   임대건물명   임대면적 전월세구분코드 전월세구분    보증금  임대료  계약년도      계약일자  \
# 0     우진빌딩  2      4  다세대/연립  82.69       1    전세  34000    0  2015  20150623
# 1  청운벽산빌리지  2      4  다세대/연립  83.61       3   준월세   5000  120  2015  20150703
# 2    MJ하이빌  3      4  다세대/연립     75       1    전세  35000    0  2015  20150921
# 3   글로리아파크  2      4  다세대/연립  79.14       1    전세  38000    0  2015  20150822
# 4    귀빈하우스  2      4  다세대/연립  102.4       1    전세  43000    0  2015  20150902
#
#      건축년도
# 0  1991.0
# 1  1988.0
# ...

# %%
df['건물명']
# Out:
# 0                               우진빌딩
# 1                            청운벽산빌리지
# 2                              MJ하이빌
# 3                             글로리아파크
# 4                              귀빈하우스
#                      ...
# 3280916                   마곡일성트루엘플래닛
# 3280917                 힐스테이트 에코 마곡역
# 3280918                       퀸즈오피스텔
# 3280919    힐스테이트에코 마곡나루역 라마다앙코르 서울마곡
# 3280920                       강서메트로칸
# Name: 건물명, Length: 3280921, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280921 entries, 0 to 3280920
# Data columns (total 22 columns):
# 지번코드       object
# 기관코드       object
# 일련번호       object
# 접수년도       object
# 자치구코드      object
# 자치구명       object
# 법정동코드      object
# 법정동명       object
# 본번         object
# 부번         object
# 건물명        object
# 층          object
# 임대건물코드     object
# 임대건물명      object
# 임대면적       object
# 전월세구분코드    object
# 전월세구분      object
# 보증금        object
# 임대료        object
# 계약년도       object
# 계약일자       object
# 건축년도       float64
# dtypes: float64(1), object(21)
# memory usage: 550.7+ MB

# %%
df['계약일자'].str.slice(start=0, stop=6).astype('float').min()
# Out:
# 1957.0

# %%
df[df['계약일자']=='1957']
# Out:
#              지번코드     기관코드 일련번호  접수년도  자치구코드 자치구명  법정동코드 법정동명   본번   부번  ...  \
# 46738  1114013600  3010045  105  2017  11140   중구  13600  묵정동  NaN  NaN  ...
#
#       임대건물코드        임대건물명 임대면적 전월세구분코드 전월세구분 보증금   임대료      계약년도  계약일자 건축년도
# 46738      2  단독/다가구;"18"    3     준월세   500  40  2017  20170607  1957  NaN
#
# [1 rows x 22 columns]

# %%
df[df['계약일자'].str.slice(start=0, stop=4).fillna(0.0).astype('float') != 0.0]
# Out:
#                         지번코드     기관코드  일련번호  접수년도  자치구코드 자치구명  법정동코드 법정동명  \
# 0        1111010100100740001  3000136   457  2015  11110  종로구  10100  청운동
# 1        1111010100100010000  3000136   485  2015  11110  종로구  10100  청운동
# 2        1111010100100560041  3000136     5  2016  11110  종로구  10100  청운동
# 3        1111010100100500010  3000136   505  2015  11110  종로구  10100  청운동
# 4        1111010100100520018  3000136   637  2015  11110  종로구  10100  청운동
# 5        1111010100101080014  3000136   656  2015  11110  종로구  10100  청운동
# 6        1111010100100520018  3000136   129  2018  11110  종로구  10100  청운동
# 7        1111010100100890005  3000136    38  2016  11110  종로구  10100  청운동
# 8        1111010100100010000  3000136   698  2015  11110  종로구  10100  청운동
# 9        1111010100100560041  3000136    66  2016  11110  종로구  10100  청운동
# 10       1111010100100010000  3000136   708  2015  11110  종로구  10100  청운동
# 11       1111010100100890005  3000136   619  2015  11110  종로구  10100  청운동
# ...

# %%
전세 = df[df['전월세구분코드']=='1']

# %%
전세.to_csv('jeonse.csv',encoding='euc-kr')

# %%
data = pd.read_csv('jeonse.csv', encoding = 'CP949')
# Out:
# C:\Users\Yeonjoo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#                         지번코드     기관코드  일련번호  접수년도  자치구코드  자치구명  법정동코드    법정동명  \
# 0        1111010100100740001  3000136   457  2015  11110   종로구  10100     청운동
# 1        1111010100100560041  3000136     5  2016  11110   종로구  10100     청운동
# 2        1111010100100500010  3000136   505  2015  11110   종로구  10100     청운동
# 3        1111010100100520018  3000136   637  2015  11110   종로구  10100     청운동
# 4        1111010100100520018  3000136   129  2018  11110   종로구  10100     청운동
# 5        1111010100100890005  3000136    38  2016  11110   종로구  10100     청운동
# 6        1111010100100010000  3000136   698  2015  11110   종로구  10100     청운동
# 7        1111010100100560041  3000136    66  2016  11110   종로구  10100     청운동
# 8        1111010100100010000  3000136   708  2015  11110   종로구  10100     청운동
# 9        1111010100100890005  3000136   619  2015  11110   종로구  10100     청운동
# 10       1111010100100890005  3000136   598  2015  11110   종로구  10100     청운동
# ...

# %%
data = data.iloc[:,1:]

# %%
data['층'] = data['층'].fillna(0.0).astype('int32')

# %%
data['건축년도'] = data['건축년도'].fillna(0.0).astype('int32')

# %%
data['본번'] = data['본번'].fillna(0.0).astype('int32')
data['부번'] = data['부번'].fillna(0.0).astype('int32')

# %%
data.head()
# Out:
#                   지번코드     기관코드  일련번호  접수년도  자치구코드 자치구명  법정동코드 법정동명  본번  부번  \
# 0  1111010100100740001  3000136   457  2015  11110  종로구  10100  청운동  74   1
# 1  1111010100100560041  3000136     5  2016  11110  종로구  10100  청운동  56  41
# 2  1111010100100500010  3000136   505  2015  11110  종로구  10100  청운동  50  10
# 3  1111010100100520018  3000136   637  2015  11110  종로구  10100  청운동  52  18
# 4  1111010100100520018  3000136   129  2018  11110  종로구  10100  청운동  52  18
#
#       건물명  층  임대건물코드   임대건물명    임대면적  전월세구분코드 전월세구분    보증금 임대료  계약년도  \
# 0    우진빌딩  2       4  다세대/연립   82.69        1    전세  34000   0  2015
# 1   MJ하이빌  3       4  다세대/연립   75.00        1    전세  35000   0  2015
# 2  글로리아파크  2       4  다세대/연립   79.14        1    전세  38000   0  2015
# 3   귀빈하우스  2       4  다세대/연립  102.40        1    전세  43000   0  2015
# 4   귀빈하우스  2       4  다세대/연립  102.40        1    전세  43000   0  2015
#
#        계약일자  건축년도
# 0  20150623  1991
# 1  20150921  2007
# 2  20150822  2002
# ...

# %%
data['계약년도'].str.slice(start=0, stop=4).astype('float').max()
# Out:
# 2019.0

# %%
data[data['계약일자']=='1973']
# Out:
#                지번코드     기관코드  일련번호  접수년도  자치구코드  자치구명  법정동코드 법정동명  본번  부번  \
# 1180841  1156013200  3180058   435  2014  11560  영등포구  13200  신길동   0   0
# 2003932  1162010100    24410  3605  2014  11620   관악구  10100  봉천동   0   0
#
#          건물명  층  임대건물코드   임대건물명   임대면적  전월세구분코드 전월세구분   보증금       임대료  \
# 1180841  NaN  0       2  단독/다가구  29.00        1    전세  7000         0
# 2003932  NaN  0       2  단독/다가구  47.19        1    전세  7000  0;"2014"
#
#                     계약년도  계약일자  건축년도
# 1180841  2013;"20131013"  1973     0
# 2003932         20140617  1973     0

# %%
전세계약 = data[data['계약일자'].str.slice(start=0, stop=4).fillna(0.0).astype('float') != 0.0]

# %%
전세계약['계약일자'].str.slice(start=0, stop=4).fillna(0.0).astype('float').min()
# Out:
# 1973.0

# %%
전세계약[전세계약.계약일자.str.len() != 8 ]
# Out:
#                         지번코드     기관코드   일련번호  접수년도  자치구코드 자치구명  법정동코드 법정동명  \
# 2988     1111011700101000000  3000042    111  2015  11110  종로구  11700  당주동
# 24180             1114014700  3010047     95  2019  11140   중구  14700  쌍림동
# 29107    1114016200108420000  3010144    418  2017  11140   중구  16200  신당동
# 31893    1114016200108440000  3010143    298  2017  11140   중구  16200  신당동
# 98304             1120010500  3030043   1158  2012  11200  성동구  10500  마장동
# 98305    1120010500108180000  3030043    231  2018  11200  성동구  10500  마장동
# 98306    1120010500108180000  3030043    240  2018  11200  성동구  10500  마장동
# 98307    1120010500107840000  3030043    362  2018  11200  성동구  10500  마장동
# 98308    1120010500107840000  3030043    366  2018  11200  성동구  10500  마장동
# 98309    1120010500107840000  3030043    367  2018  11200  성동구  10500  마장동
# 98310    1120010500108220000  3030043    374  2018  11200  성동구  10500  마장동
# ...

# %%
전세계약[전세계약['계약일자'] =='1973']
# Out:
#                지번코드     기관코드  일련번호  접수년도  자치구코드  자치구명  법정동코드 법정동명  본번  부번  \
# 1180841  1156013200  3180058   435  2014  11560  영등포구  13200  신길동   0   0
# 2003932  1162010100    24410  3605  2014  11620   관악구  10100  봉천동   0   0
#
#          건물명  층  임대건물코드   임대건물명   임대면적  전월세구분코드 전월세구분   보증금       임대료  \
# 1180841  NaN  0       2  단독/다가구  29.00        1    전세  7000         0
# 2003932  NaN  0       2  단독/다가구  47.19        1    전세  7000  0;"2014"
#
#                     계약년도  계약일자  건축년도
# 1180841  2013;"20131013"  1973     0
# 2003932         20140617  1973     0
